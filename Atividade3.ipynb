# %% [markdown]
# # 📊 Exercícios: Estatística em Ação
# ## **Python para Análise de Dados**
# ## Instruções
# - A Atividade deve ser realizada até 23:59 do dia da aula (03/07) e o envio deve ser realizado por meio do GitHub

# %% [markdown]
# # Questão 1
# Crie quatro variáveis para armazenar as seguintes informações sobre um produto:
#
# - Nome: "NVIDIA GeForce RTX 5090" (tipo texto).
# - Quantidade de RAM: 32 (tipo inteiro).
# - Preço: 10.871,36 (tipo decimal).
# - Em estoque: True (tipo booleano).
#
# Após criar as variáveis, utilize a função `print()` e `type()` para exibir o valor e o tipo de cada uma delas no console.

# %%
Nome = "NVIDIA GeForce RTX 5090"
Quantidade = 32
Preco = 10871.36
Estoque = True

print(f"Nome: {Nome}\nquantidade: {Quantidade}\nPreço: R${Preco}\nEm estoque: {Estoque}")
print(f"type(Nome): {type(Nome)} \ntype(Quantidade): {type(Quantidade)} \ntype(Preco): {type(Preco)} \ntype(Estoque): {type(Estoque)}")
# Out:
# Nome: NVIDIA GeForce RTX 5090
# quantidade: 32
# Preço: R$10871.36
# Em estoque: True
# type(Nome): <class 'str'>
# type(Quantidade): <class 'int'>
# type(Preco): <class 'float'>
# type(Estoque): <class 'bool'>

# %% [markdown]
# # Questão 2
# Imagine que você está preparando o seu ambiente de programação e organizando as bibliotecas que usará para manipulação e visualização de dados.
#
# 1. Comente do que se trata a lista
#
# 2. Crie uma lista chamada pacotes com os valores: "tidyverse", "plotly", "gtsummary"
#
# 3. Adicione o pacote "shiny" ao final da lista.
#
# 4. Remova o pacote "plotly".
#
# 5. Ordene a lista em ordem alfabética.

# %%
# Pacotes de R
pacotes = ["tidyverse", "plotly", "gtsummary"]
pacotes.append("shiny")
pacotes.remove("plotly")
pacotes.sort()

print(pacotes)
# Out:
# ['gtsummary', 'shiny', 'tidyverse']

# %% [markdown]
# # Questão 3
# Represente dados de um disciplina de um sistema acadêmico.
#
# 1. Crie um dicionário chamado disciplina com as chaves: "nome", "vagas" e "professor".
#
# 2. Imprima apenas as chaves do dicionário.
#
# 3. Imprima apenas os valores do dicionário.
#
# 4. Use o método .get() para buscar a chave "sala". Caso não exista, o Python não deve retornar erro.

# %%
disciplina = {
    "nome": "Estatística em Ação",
    "vagas": 30,
    "professor": "Daniel"
}

print(disciplina.keys())
print(disciplina.values())
print(disciplina.get("sala"))
# Out:
# dict_keys(['nome', 'vagas', 'professor'])
# dict_values(['Estatística em Ação', 30, 'Daniel'])
# None

# %% [markdown]
# # 🏆 Desafio Final - Frota Logística
#
# Você foi contratado para criar o sistema interno de um aplicativo de entregas. Sua missão é organizar as informações dos veículos disponíveis utilizando as estruturas de dados adequadas que aprendeu hoje:
#
# 1. Última Rota (Tupla): Crie uma tupla imutável para guardar as coordenadas geográficas (Latitude e Longitude) do último ponto de entrega do veículo (ex: (-7.115, -34.863)).
#
# 2. Ficha do Veículo (Dicionário): Cada veículo deve ser representado por um dicionário contendo as seguintes chaves:
#
# - modelo (str)
#
# - ano (int)
#
# - capacidade_kg (float)
#
# - em_operacao (bool)
#
# - ultima_coordenada (a tupla criada no passo 1)
#
# 3- Frota Ativa (Lista): Agrupe os dicionários de pelo menos dois veículos dentro de uma única lista chamada frota_aplicativo.

# %%
# Criando tuplas com as coordenadas (Latitude, Longitude)
coordenadas_veiculo1 = (-7.115, -34.863)
coordenadas_veiculo2 = (-23.550, -46.633)

# Criando o dicionário para o primeiro veículo
veiculo1 = {
    "modelo": "Fiat Fiorino",
    "ano": 2021,
    "capacidade_kg": 650.0,
    "em_operacao": True,
    "ultima_coordenada": coordenadas_veiculo1
}

# Criando o dicionário para o segundo veículo
veiculo2 = {
    "modelo": "Renault Kangoo",
    "ano": 2019,
    "capacidade_kg": 800.5,
    "em_operacao": False,
    "ultima_coordenada": coordenadas_veiculo2
}

# Agrupando os dicionários em uma única lista
frota_aplicativo = [veiculo1, veiculo2]

print("Frota do Aplicativo de Entregas:")
for veiculo in frota_aplicativo:
    print(veiculo)
# Out:
# Frota do Aplicativo de Entregas:
# {'modelo': 'Fiat Fiorino', 'ano': 2021, 'capacidade_kg': 650.0, 'em_operacao': True, 'ultima_coordenada': (-7.115, -34.863)}
# {'modelo': 'Renault Kangoo', 'ano': 2019, 'capacidade_kg': 800.5, 'em_operacao': False, 'ultima_coordenada': (-23.55, -46.633)}
